# %% [markdown]
# # HART-Morphosis: HART Core Demo
# ### A Hybrid Autoregressive Transformer with Morpho-Cosmo Attention

# %%
import torch
from src.hart_morphosis.core import HART

# Initialize HART model
model = HART(d_model=16, num_layers=2)
input_tensor = torch.randn(1, 16, 16, 16)
output = model(input_tensor)

print(f"Input shape: {input_tensor.shape}")
print(f"Output shape: {output.shape}")
print(f"Pixel range: [{output.min():.3f}, {output.max():.3f}]")
