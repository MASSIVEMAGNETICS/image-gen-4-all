# %% [markdown]
# # Fractal Renderer Zoom Demo
# ### Infinite resolution via recursive scaling

# %%
from IPython.display import display
import torch
from src.hart_morphosis.core import FractalRenderer

base = torch.rand(16, 16, 3)
renderer = FractalRenderer(base_resolution=(16, 16))

for zoom in [1, 2, 4]:
    zoomed = renderer.render_zoom_level(base, zoom_level=zoom)
    display(renderer.tensor_to_pil(zoomed))
