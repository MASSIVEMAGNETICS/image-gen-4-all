# %% [markdown]
# # Morphogenesis Engine Demo
# ### Reaction-Diffusion Pattern Growth

# %%
from IPython.display import display
from src.hart_morphosis.core import FractalRenderer, MorphogenesisEngine

engine = MorphogenesisEngine(grid_size=(32, 32))
pattern = engine.generate_pattern(steps=60, seed=7)
renderer = FractalRenderer(base_resolution=(32, 32))

img = renderer.tensor_to_pil(pattern)
display(img)
